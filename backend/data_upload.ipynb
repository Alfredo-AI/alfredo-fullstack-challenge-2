# %%
#visualize the various JSON files using Jupyter notebook with Pandas

import pandas as pd

df_subscription = pd.read_json('/home/dinis/Desktop/alfredo-fullstack-challenge-2/data/subscriptions.json')
df_user = pd.read_json('/home/dinis/Desktop/alfredo-fullstack-challenge-2/data/users.json')

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker




engine = create_engine("postgresql+asyncpg://admin:thisisatest@127.0.0.1:5432/alfredo")

Session = sessionmaker(bind=engine)

session = Session()

for _ in df_user.iterrows():
    print("test")

#ed_user = User(name=)
conn = engine.connect()



df_subscription.to_sql('subscription', con=conn, if_exists = 'replace', index=False)
# Out:
#   Cell In[9], line 13
#     ed_user = User(name=)
#                         ^
# SyntaxError: invalid syntax

# %%
df_subscription
# Out:
#         id             date_init              date_end    status  user_id  \
# 0        1  12/02/2021, 00:00:00  12/02/2022, 23:59:59  canceled        1
# 1        0  12/02/2021, 00:00:00  12/02/2022, 23:59:59  past_due        0
# 2        3  06/23/2022, 00:00:00  07/23/2022, 23:59:59  canceled        3
# 3        2  06/23/2022, 00:00:00  07/23/2022, 23:59:59  past_due        2
# 4        5  06/22/2022, 00:00:00  08/22/2022, 23:59:59  canceled        5
# ...    ...                   ...                   ...       ...      ...
# 4869  4868  02/20/2024, 00:00:00  02/20/2024, 16:31:31    active     7281
# 4870  4871  02/20/2024, 00:00:00  02/20/2025, 23:59:59  canceled     7286
# 4871  4870  02/20/2024, 00:00:00  02/20/2025, 23:59:59    active     7285
# 4872  4873  02/20/2024, 00:00:00  02/20/2025, 23:59:59  canceled     7290
# 4873  4872  02/20/2024, 00:00:00  02/20/2025, 23:59:59    active     7289
#
#        reason
# 0     closing
# 1        None
# 2        team
# 3        None
# ...

# %%
df_user
# Out:
#         id       name                  email  \
# 0        0     user_0     user_0@gmailll.com
# 1        1     user_1     user_1@gmailll.com
# 2        2     user_2     user_2@gmailll.com
# 3        3     user_3     user_3@gmailll.com
# 4        4     user_4     user_4@gmailll.com
# ...    ...        ...                    ...
# 7288  7288  user_7288  user_7288@gmailll.com
# 7289  7289  user_7289  user_7289@gmailll.com
# 7290  7290  user_7290  user_7290@gmailll.com
# 7291  7291  user_7291  user_7291@gmailll.com
# 7292  7292  user_7292  user_7292@gmailll.com
#
#                              public_id  account_type     registration_date  \
# 0     dda6ec076a3a41bda7a6b118f7f535f5  professional  03/17/2021, 19:27:56
# 1     0b206b6402d5452795dcfdbf78f8f58e  professional  03/17/2021, 19:27:56
# 2     3fee7c2b69734af29a856a8bf5ec083b       regular  05/15/2022, 10:54:23
# 3     ce11e31c7af945f691bf00ae1cb545df       regular  05/15/2022, 10:54:23
# ...
